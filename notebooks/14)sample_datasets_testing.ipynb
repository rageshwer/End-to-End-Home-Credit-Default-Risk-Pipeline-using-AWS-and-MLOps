# %%
import pandas as pd

# %%
app_train=pd.read_csv('/Users/rageshwer/Goal ML/Projects/Home_Credit_Default_Risk/data/raw/application_train.csv')
app_test=pd.read_csv('/Users/rageshwer/Goal ML/Projects/Home_Credit_Default_Risk/data/raw/application_test.csv')
bureau=pd.read_csv('/Users/rageshwer/Goal ML/Projects/Home_Credit_Default_Risk/data/raw/bureau.csv')
bb=pd.read_csv('/Users/rageshwer/Goal ML/Projects/Home_Credit_Default_Risk/data/raw/bureau_balance.csv')

# %%
app_train_sample=app_train.sample(2000,random_state=42)
app_test_sample=app_test.sample(2000,random_state=42)
sample_ids=app_train_sample['SK_ID_CURR'].tolist()

# %%
bureau_sample=bureau[bureau['SK_ID_CURR'].isin(sample_ids)].sample(5000,random_state=42)
bureau_ids=bureau_sample['SK_ID_BUREAU'].tolist()

# %%
bureau_balance_sample=bb[bb['SK_ID_BUREAU'].isin(bureau_ids)].sample(8000,random_state=42)

# %%
app_train_sample.to_csv('/Users/rageshwer/Goal ML/Projects/Home_Credit_Default_Risk/tests/mock_data/raw/application_train_sample.csv',index=False)
app_test_sample.to_csv('/Users/rageshwer/Goal ML/Projects/Home_Credit_Default_Risk/tests/mock_data/raw/application_test_sample.csv',index=False)
bureau_sample.to_csv('/Users/rageshwer/Goal ML/Projects/Home_Credit_Default_Risk/tests/mock_data/raw/bureau_sample.csv',index=False)
bureau_balance_sample.to_csv('/Users/rageshwer/Goal ML/Projects/Home_Credit_Default_Risk/tests/mock_data/raw/bureau_balance_sample.csv',index=False)
