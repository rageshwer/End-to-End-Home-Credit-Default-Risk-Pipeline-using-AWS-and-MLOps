# %% [markdown]
# # || EDA 'bureau_balance.csv' ||
# This gives the monthly data of the CB credits. The FK is BUREAU_ID. For each bureau credit, this given the monthly record.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("All libraries imported!")
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# Out:
# All libraries imported!

# %%
bureau_bal=pd.read_csv('/Users/rageshwer/Goal ML/Projects/Home_Credit_Default_Risk/data/raw/bureau_balance.csv')
bureau_bal
# Out:
#           SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0              5715448               0      C
# 1              5715448              -1      C
# 2              5715448              -2      C
# 3              5715448              -3      C
# 4              5715448              -4      C
# ...                ...             ...    ...
# 27299920       5041336             -47      X
# 27299921       5041336             -48      X
# 27299922       5041336             -49      X
# 27299923       5041336             -50      X
# 27299924       5041336             -51      X
#
# [27299925 rows x 3 columns]

# %%
# Has monthly record of 817395 loans of the bureau file. 
bureau_bal['SK_ID_BUREAU'].nunique()
# Out:
# 817395

# %%
# No missing values
bureau_bal.isna().sum()
# Out:
# SK_ID_BUREAU      0
# MONTHS_BALANCE    0
# STATUS            0
# dtype: int64

# %%
# categories
bureau_bal['STATUS'].unique()
# Out:
# <ArrowStringArray>
# ['C', '0', 'X', '1', '2', '3', '5', '4']
# Length: 8, dtype: str

# %%
# How many months data is available per loan record.
bureau_bal.groupby('SK_ID_BUREAU')['MONTHS_BALANCE'].count()
# Out:
# SK_ID_BUREAU
# 5001709    97
# 5001710    83
# 5001711     4
# 5001712    19
# 5001713    22
#            ..
# 6842884    48
# 6842885    24
# 6842886    33
# 6842887    37
# 6842888    62
# Name: MONTHS_BALANCE, Length: 817395, dtype: int64

# %% [markdown]
# # || Observations ||
# 1. This contains the monthly credit history of the credits in the bureau file.
# 2. The status is giving important information about the repayment stress, if any.
# 3. Bureau_balance contains repayment-history records for only a subset of bureau credits (~817k out of ~1.7M credit records). Therefore, monthly delinquency information is unavailable for all credits and feature engineering must account for missing bureau_balance history after merging. The availability of bureau_balance itself may carry predictive information and can be converted into a feature such as HAS_BUREAU_BALANCE_HISTORY.
