# %% [markdown]
# This is a initial dataset loading and inspecting the size and values present in the dataset.

# %%
import pandas as pd

# %%
app_train=pd.read_csv('/Users/rageshwer/Goal ML/Projects/Home_Credit_Default_Risk/data/raw/application_train.csv')
app_test=pd.read_csv('/Users/rageshwer/Goal ML/Projects/Home_Credit_Default_Risk/data/raw/application_test.csv')
bureau=pd.read_csv('/Users/rageshwer/Goal ML/Projects/Home_Credit_Default_Risk/data/raw/bureau.csv')
bureau_balance=pd.read_csv('/Users/rageshwer/Goal ML/Projects/Home_Credit_Default_Risk/data/raw/bureau_balance.csv')
cc_bal=pd.read_csv('/Users/rageshwer/Goal ML/Projects/Home_Credit_Default_Risk/data/raw/credit_card_balance.csv')
installments=pd.read_csv('/Users/rageshwer/Goal ML/Projects/Home_Credit_Default_Risk/data/raw/installments_payments.csv')
pos=pd.read_csv('/Users/rageshwer/Goal ML/Projects/Home_Credit_Default_Risk/data/raw/POS_CASH_balance.csv')
prev_app=pd.read_csv('/Users/rageshwer/Goal ML/Projects/Home_Credit_Default_Risk/data/raw/previous_application.csv')

# %%
dataset_inventory=pd.DataFrame({
    'Datasets':['app_train','app_test','bureau','bureau_balance','cc_bal','installments','pos','prev_app'],
    'Rows':[app_train.shape[0],app_test.shape[0],bureau.shape[0],bureau_balance.shape[0],cc_bal.shape[0],installments.shape[0],pos.shape[0],prev_app.shape[0]],
    'Columns':[app_train.shape[1],app_test.shape[1],bureau.shape[1],bureau_balance.shape[1],cc_bal.shape[1],installments.shape[1],pos.shape[1],prev_app.shape[1]],
    'Unique SK_ID':[app_train['SK_ID_CURR'].nunique(),app_test['SK_ID_CURR'].nunique(),bureau['SK_ID_CURR'].nunique(),bureau_balance['SK_ID_BUREAU'].nunique(),cc_bal['SK_ID_CURR'].nunique(),installments['SK_ID_CURR'].nunique(),pos['SK_ID_CURR'].nunique(),prev_app['SK_ID_CURR'].nunique()],
    'Primary Key':['SK_ID_CURR','SK_ID_CURR','SK_ID_CURR','SK_ID_BUREAU','SK_ID_CURR','SK_ID_CURR','SK_ID_CURR','SK_ID_CURR']
})
dataset_inventory
# Out:
#          Datasets      Rows  Columns  Unique SK_ID   Primary Key
# 0       app_train    307511      122        307511    SK_ID_CURR
# 1        app_test     48744      121         48744    SK_ID_CURR
# 2          bureau   1716428       17        305811    SK_ID_CURR
# 3  bureau_balance  27299925        3        817395  SK_ID_BUREAU
# 4          cc_bal   3840312       23        103558    SK_ID_CURR
# 5    installments  13605401        8        339587    SK_ID_CURR
# 6             pos  10001358        8        337252    SK_ID_CURR
# 7        prev_app   1670214       37        338857    SK_ID_CURR
